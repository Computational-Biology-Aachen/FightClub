# %%
import pandas as pd

# Path to the uploaded Excel file
file_path = 'C:\\Users\\Tanvir Hassan\\Tripertile population dynamics\\Growth_data_(replicates_combined).xlsx'

df = pd.read_excel(file_path, sheet_name='1_2)7942_1_UMa_0.1')  # Replace 'Sheet1' if needed

# Display the DataFrame
print(df)
