# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate the growth rate
def calculate_growth_rate(time, cell_counts):
    # Initial cell count (N0) is the first element in the cell_counts
    N0 = cell_counts[0]
    
    # Taking the natural log of the ratio of cell count at each time point
    ln_ratio = np.log(cell_counts / N0)
    
    # Finding the growth rate r as the slope of the linear fit between ln_ratio and time
    growth_rate, intercept = np.polyfit(time, ln_ratio, 1)
    
    return growth_rate, ln_ratio

# Load the Excel file with data
file_path = r"C:\Users\Tanvir Hassan\OneDrive\Desktop\Mibinet\B01 data julich\mono culture\4018 C. glutamicum WT in CGXII +10 gL-1 glucose + PCA.xlsx"


# Display the data as a pandas DataFrame
print("Data from the Excel file:")
print("data")

# Assuming the Excel file has columns named 'Time' and 'Cell_Count'
time = data['Time'].values  # Time data
cell_counts = data['Cell_Count'].values  # Cell count data

# Calculate the growth rate and the log-transformed ratios
growth_rate, ln_ratio = calculate_growth_rate(time, cell_counts)

# Display the calculated growth rate
print(f"\nEstimated growth rate: {growth_rate:.4f}")

# Plotting the original cell counts
plt.figure(figsize=(10, 5))

# Subplot 1: Plot of original cell count vs time
plt.subplot(1, 2, 1)
plt.plot(time, cell_counts, 'bo-', label='Cell Count')
plt.xlabel('Time (hours)')
plt.ylabel('Cell Count')
plt.title('Exponential Growth of Cell Count')
plt.grid(True)
plt.legend()

# Subplot 2: Plot of log-transformed cell count ratio vs time
plt.subplot(1, 2, 2)
plt.plot(time, ln_ratio, 'ro-', label='ln(Cell Count / Initial Cell Count)')
plt.xlabel('Time (hours)')
plt.ylabel('ln(N/N0)')
plt.title('Log-Transformed Cell Count vs Time')
plt.grid(True)
plt.legend()

# Display both plots
plt.tight_layout()
plt.show()
# Out:
# Data from the Excel file:
# data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 27
#      24 print("data")
#      26 # Assuming the Excel file has columns named 'Time' and 'Cell_Count'
# ---> 27 time = data['Time'].values  # Time data
#      28 cell_counts = data['Cell_Count'].values  # Cell count data
#      30 # Calculate the growth rate and the log-transformed ratios
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# File path to the Excel file (use raw string or double backslashes)
file_path = r"C:\Users\Tanvir Hassan\OneDrive\Desktop\Mibinet\B01 data julich\mono culture\4018 C. glutamicum WT in CGXII +10 gL-1 glucose + PCA.xlsx"

# Try to load the Excel file
try:
    data = pd.read_excel(file_path)
    print("Excel file loaded successfully.")
except Exception as e:
    print(f"Error loading Excel file: {e}")

# Check if data is loaded and display the first few rows
if 'data' in locals():
    print("Data from the Excel file:")
    print(data.head())  # Show first few rows of the data
else:
    print("Data not loaded. Please check the file path and format.")

# Assuming the Excel file has columns named 'Time' and 'Cell_Count'
# If your columns are named differently, adjust them here
if 'Time' in data.columns and 'Cell_Count' in data.columns:
    time = data['Time'].values  # Time data
    cell_counts = data['Cell_Count'].values  # Cell count data
else:
    print("Error: Excel file does not contain 'Time' or 'Cell_Count' columns.")

# Function to calculate the growth rate
def calculate_growth_rate(time, cell_counts):
    # Initial cell count (N0) is the first element in the cell_counts
    N0 = cell_counts[0]
    
    # Taking the natural log of the ratio of cell count at each time point
    ln_ratio = np.log(cell_counts / N0)
    
    # Finding the growth rate r as the slope of the linear fit between ln_ratio and time
    growth_rate, intercept = np.polyfit(time, ln_ratio, 1)
    
    return growth_rate, ln_ratio

# Calculate the growth rate and the log-transformed ratios if data is valid
if 'time' in locals() and 'cell_counts' in locals():
    growth_rate, ln_ratio = calculate_growth_rate(time, cell_counts)

    # Display the calculated growth rate
    print(f"\nEstimated growth rate: {growth_rate:.4f}")

    # Plotting the original cell counts
    plt.figure(figsize=(10, 5))

    # Subplot 1: Plot of original cell count vs time
    plt.subplot(1, 2, 1)
    plt.plot(time, cell_counts, 'bo-', label='Cell Count')
    plt.xlabel('Time (hours)')
    plt.ylabel('Cell Count')
    plt.title('Exponential Growth of Cell Count')
    plt.grid(True)
    plt.legend()

    # Subplot 2: Plot of log-transformed cell count ratio vs time
    plt.subplot(1, 2, 2)
    plt.plot(time, ln_ratio, 'ro-', label='ln(Cell Count / Initial Cell Count)')
    plt.xlabel('Time (hours)')
    plt.ylabel('ln(N/N0)')
    plt.title('Log-Transformed Cell Count vs Time')
    plt.grid(True)
    plt.legend()

    # Display both plots
    plt.tight_layout()
    plt.show()
# Out:
# Error loading Excel file: [Errno 13] Permission denied: 'C:\\Users\\Tanvir Hassan\\OneDrive\\Desktop\\Mibinet\\B01 data julich\\mono culture\\4018 C. glutamicum WT in CGXII +10 gL-1 glucose + PCA.xlsx'
# Data not loaded. Please check the file path and format.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 24
#      20     print("Data not loaded. Please check the file path and format.")
#      22 # Assuming the Excel file has columns named 'Time' and 'Cell_Count'
#      23 # If your columns are named differently, adjust them here
# ---> 24 if 'Time' in data.columns and 'Cell_Count' in data.columns:
#      25     time = data['Time'].values  # Time data
#      26     cell_counts = data['Cell_Count'].values  # Cell count data
#
# NameError: name 'data' is not defined

# %%
import numpy as np

# Function to calculate the growth rate
def calculate_growth_rate(time, cell_counts):
    # Assuming time and cell_counts are numpy arrays or lists
    # Initial cell count (N0) is the first element in the cell_counts
    N0 = cell_counts[0]
    
    # Taking the natural log of the ratio of cell count at each time point
    ln_ratio = np.log(cell_counts / N0)
    
    # Finding the growth rate r as the slope of the linear fit between ln_ratio and time
    growth_rate, intercept = np.polyfit(time, ln_ratio, 1)
    
    return growth_rate

# Example data (time in hours, cell count at different times)
time = np.array([0, 2, 4, 6, 8, 10])  # Time in hours
cell_counts = np.array([16, 18, 19, 21, 36, 86])  # Cell counts

# Calculate the growth rate
growth_rate = calculate_growth_rate(time, cell_counts)

print(f"Estimated growth rate: {growth_rate:.4f}")
# Out:
# Estimated growth rate: 0.1513

# %%
import pandas as pd

# %%
import pandas as pd


df = pd.read_excel(r"C:\Users\Tanvir Hassan\Tripertile population dynamics\Sucrose_production_rate.xlsx")

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\envs\mibinet\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\anaconda3\envs\mibinet\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Tanvir Hassan\anaconda3\envs\mibinet\python.exe

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Tanvir Hassan\anaconda3\envs\mibinet\python.exe

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Tanvir Hassan\anaconda3\envs\mibinet\python.exe
